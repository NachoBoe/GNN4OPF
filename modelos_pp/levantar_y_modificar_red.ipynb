# %%
import pandapower as pp

net = pp.from_pickle("red_uru copy.p")

# %%
net.line.c_nf_per_km /= 3

# %%
pp.to_pickle(net, './red_uru_final.p')  # absolute path

# %%
from torch import nn
import torch
loss = nn.MSELoss(reduction='none')

# %%
a = torch.ones((20,30,2))
a[:,:,1] *= 10
b = a * 0.9

# %%
loss_w = torch.Tensor([1/0.01, 1])
loss(a,b)
torch.matmul(loss(a,b) , loss_w)
# Out:
# tensor([[2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
#          2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
#          2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
#          2.0000, 2.0000, 2.0000],
#         [2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
#          2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
#          2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
#          2.0000, 2.0000, 2.0000],
#         [2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
#          2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
#          2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
#          2.0000, 2.0000, 2.0000],
#         [2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000, 2.0000,
# ...
